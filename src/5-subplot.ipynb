# %% [markdown]
# <a href="https://colab.research.google.com/github/Udayaraniboya/python-jupyter-template/blob/main/src/5-subplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Line Plot
x = [1, 2, 3, 4, 5]
y = [i**2 for i in x]
axs[0, 0].plot(x, y, marker='o', color='blue')
axs[0, 0].set_title("Line Plot")

# Bar Chart
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 9]
axs[0, 1].bar(categories, values, color='green')
axs[0, 1].set_title("Bar Chart")

# Scatter Plot
x_scatter = [1, 2, 3, 4, 5]
y_scatter = [2, 4, 6, 8, 10]
axs[1, 0].scatter(x_scatter, y_scatter, color='purple', marker='*')
axs[1, 0].set_title("Scatter Plot")

# Pie Chart
labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [40, 25, 20, 15]
axs[1, 1].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
axs[1, 1].set_title("Pie Chart")
axs[1, 1].axis('equal')

plt.tight_layout(pad=2.0)
plt.show()
